# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")

# %%
model.train(
    data="chart_detection.yaml",
    epochs=10,
    imgsz=640,
    batch=5,
    workers=4
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.79 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.78  Python-3.10.11 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# ...
